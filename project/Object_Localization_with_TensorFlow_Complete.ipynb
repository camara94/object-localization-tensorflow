# %% [markdown]
# # Object Localization with TensorFlow
#
# Created for the Coursera Guided Project: [Object Localization with TensorFlow](https://www.coursera.org/projects/object-localization-tensorflow)
#
# ![ObjectLocalizationExample.jpg](data:image/jpeg;base64,...)
#
# All emojis designed by [OpenMoji](https://openmoji.org/) – the open-source emoji and icon project. License: CC BY-SA 4.0

# %% [markdown]
# ## Task 2: Download and Visualize Data

# %%
# !wget https://github.com/hfg-gmuend/openmoji/releases/latest/download/openmoji-72x72-color.zip
# !mkdir emojis
# !unzip -q openmoji-72x72-color.zip -d ./emojis
# !pip install -q tensorflow

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.8.0'

# %%
# %matplotlib inline

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

from PIL import Image, ImageDraw
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPool2D, BatchNormalization, Dropout

print('Check if using TensorFlow 2.4')
print('Using TensorFlow version', tf.__version__)
# Out:
# Check if using TensorFlow 2.4
# Using TensorFlow version 2.8.0

# %%
emojis = {
    0: {'name': 'happy', 'file': '1F642.png'},
    1: {'name': 'laughing', 'file': '1F602.png'},
    2: {'name': 'skeptical', 'file': '1F928.png'},
    3: {'name': 'sad', 'file': '1F630.png'},
    4: {'name': 'cool', 'file': '1F60E.png'},
    5: {'name': 'whoa', 'file': '1F62F.png'},
    6: {'name': 'crying', 'file': '1F62D.png'},
    7: {'name': 'puking', 'file': '1F92E.png'},
    8: {'name': 'nervous', 'file': '1F62C.png'}
}

plt.figure(figsize=(9, 9))

for i, (j, e) in enumerate(emojis.items()):
    plt.subplot(3, 3, i + 1)
    plt.imshow(plt.imread(os.path.join('emojis', e['file'])))
    plt.xlabel(e['name'])
    plt.xticks([])
    plt.yticks([])
plt.show()

# %% [markdown]
# ## Task 3: Create Examples

# %%
for class_id, values in emojis.items():
    png_file = Image.open(os.path.join('emojis', values['file'])).convert('RGBA')
    png_file.load()
    new_file = Image.new("RGB", png_file.size, (255, 255, 255))
    new_file.paste(png_file, mask=png_file.split()[3])
    emojis[class_id]['image'] = new_file

# %%
emojis
# Out:
# {0: {'name': 'happy',
#   'file': '1F642.png',
#   'image': <PIL.Image.Image image mode=RGB size=72x72 at 0x2E5C95CE940>},
#  1: {'name': 'laughing',
#   'file': '1F602.png',
#   'image': <PIL.Image.Image image mode=RGB size=72x72 at 0x2E5C95CE280>},
#  2: {'name': 'skeptical',
#   'file': '1F928.png',
#   'image': <PIL.Image.Image image mode=RGB size=72x72 at 0x2E5C967DD00>},
#  3: {'name': 'sad',
#   'file': '1F630.png',
#   'image': <PIL.Image.Image image mode=RGB size=72x72 at 0x2E5C95641C0>},
#  4: {'name': 'cool',
#   'file': '1F60E.png',
#   'image': <PIL.Image.Image image mode=RGB size=72x72 at 0x2E5C95CE880>},
#  5: {'name': 'whoa',
#   'file': '1F62F.png',
#   'image': <PIL.Image.Image image mode=RGB size=72x72 at 0x2E5C95CED00>},
#  6: {'name': 'crying',
#   'file': '1F62D.png',
#   'image': <PIL.Image.Image image mode=RGB size=72x72 at 0x2E5C9564400>},
#  7: {'name': 'puking',
#   'file': '1F92E.png',
#   'image': <PIL.Image.Image image mode=RGB size=72x72 at 0x2E5C9564430>},
#  8: {'name': 'nervous',
#   'file': '1F62C.png',
#   'image': <PIL.Image.Image image mode=RGB size=72x72 at 0x2E5C955D250>}}

# %%
def create_example():
  class_id = np.random.randint(0, 9)
  image = np.ones((144, 144, 3)) * 255
  row = np.random.randint(0, 72)
  col = np.random.randint(0, 72)
  image[row: row + 72, col: col + 72, :] = np.array(emojis[class_id]['image'])
  return image.astype('uint8'), class_id, (row + 10) / 144, (col + 10) / 144

# %%
image, class_id, row, col = create_example()
plt.imshow(image);

# %% [markdown]
# ## Task 4: Plot Bounding Boxes

# %%
def plot_bounding_box(image, gt_coords, pred_coords=[], norm=False):
  if norm:
    image *= 255.
    image = image.astype('uint8')
  image = Image.fromarray(image)
  draw = ImageDraw.Draw(image)

  row, col = gt_coords
  row *= 144
  col *= 144
  draw.rectangle((col, row, col + 52, row + 52), outline='green', width=3)

  if len(pred_coords) == 2:
    row, col = pred_coords
    row *= 144
    col *= 144
    draw.rectangle((col, row, col + 52, row + 52), outline='red', width=3)
  return image

# %%
image = plot_bounding_box(image, gt_coords=[row, col])
plt.imshow(image)
plt.title(emojis[class_id]['name'])
plt.show()

# %% [markdown]
# ## Task 5: Data Generator

# %%
def data_generator(batch_size=16):
  while True:
    x_batch = np.zeros((batch_size, 144, 144, 3))
    y_batch = np.zeros((batch_size, 9))
    bbox_batch = np.zeros((batch_size, 2))

    for i in range(0, batch_size):
      image, class_id, row, col = create_example()
      x_batch[i] = image / 255.
      y_batch[i, class_id] = 1.0
      bbox_batch[i] = np.array([row, col])
    yield {'image': x_batch}, {'class_out': y_batch, 'box_out': bbox_batch}

# %%
example, label = next(data_generator(1))
image = example['image'][0]
class_id = np.argmax(label['class_out'][0])
coords = label['box_out'][0]

image = plot_bounding_box(image, coords, norm=True)
plt.imshow(image)
plt.title(emojis[class_id]['name'])
plt.show()

# %% [markdown]
# ## Task 6: Model

# %%
input_ = Input(shape=(144, 144, 3), name='image')

x = input_

for i in range(0, 5):
  n_filters = 2**(4 + i)
  x = Conv2D(n_filters, 3, activation='relu')(x)
  x = BatchNormalization()(x)
  x = MaxPool2D(2)(x)

x = Flatten()(x)
x = Dense(256, activation='relu')(x)

class_out = Dense(9, activation='softmax', name='class_out')(x)
box_out = Dense(2, name='box_out')(x)

model = tf.keras.models.Model(input_, [class_out, box_out])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(None, 144, 144, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 142, 142, 16  448         ['image[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 142, 142, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 71, 71, 16)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 69, 69, 32)   4640        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 69, 69, 32)  128         ['conv2d_1[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 34, 34, 32)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 14, 14, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 128)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 5, 5, 256)    295168      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 5, 5, 256)   1024        ['conv2d_4[0][0]']
#  rmalization)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 2, 2, 256)   0           ['batch_normalization_4[0][0]']
#
#  flatten (Flatten)              (None, 1024)         0           ['max_pooling2d_4[0][0]']
#
#  dense (Dense)                  (None, 256)          262400      ['flatten[0][0]']
#
#  class_out (Dense)              (None, 9)            2313        ['dense[0][0]']
#
#  box_out (Dense)                (None, 2)            514         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 659,819
# Trainable params: 658,827
# Non-trainable params: 992
# __________________________________________________________________________________________________

# %% [markdown]
# ## Task 7: Custom Metric: IoU

# %%
class IoU(tf.keras.metrics.Metric):
  def __init__(self, **kwargs):
    super(IoU, self).__init__(**kwargs)

    self.iou = self.add_weight(name='iou', initializer='zeros')
    self.total_iou = self.add_weight(name='total_iou', initializer='zeros')
    self.num_ex = self.add_weight(name='num_ex', initializer='zeros')
  
  def update_state(self, y_true, y_pred, sample_weight=None):
    def get_box(y):
      rows, cols = y[:, 0], y[:, 1]
      rows, cols = rows * 144, cols * 144
      y1, y2 = rows, rows + 52
      x1, x2 = cols, cols + 52
      return x1, y1, x2, y2
    
    def get_area(x1, y1, x2, y2):
      return tf.math.abs(x2 - x1) * tf.math.abs(y2 - y1)
    
    gt_x1, gt_y1, gt_x2, gt_y2 = get_box(y_true)
    p_x1, p_y1, p_x2, p_y2 = get_box(y_pred)

    i_x1 = tf.maximum(gt_x1, p_x1)
    i_y1 = tf.maximum(gt_y1, p_y1)
    i_x2 = tf.minimum(gt_x2, p_x2)
    i_y2 = tf.minimum(gt_y2, p_y2)

    i_area = get_area(i_x1, i_y1, i_x2, i_y2)
    u_area = get_area(gt_x1, gt_y1, gt_x2, gt_y2) + get_area(p_x1, p_y1, p_x2, p_y2) - i_area

    iou = tf.math.divide(i_area, u_area)
    self.num_ex.assign_add(1)
    self.total_iou.assign_add(tf.reduce_mean(iou))
    self.iou = tf.math.divide(self.total_iou, self.num_ex)
  
  def result(self):
    return self.iou
  
  def reset_state(self):
    self.iou = self.add_weight(name='iou', initializer='zeros')
    self.total_iou = self.add_weight(name='total_iou', initializer='zeros')
    self.num_ex = self.add_weight(name='num_ex', initializer='zeros')

# %% [markdown]
# ## Task 8: Compile the Model

# %%
model.compile(
    loss={
        'class_out': 'categorical_crossentropy',
        'box_out': 'mse'
    },
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    metrics={
        'class_out': 'accuracy',
        'box_out': IoU(name='iou')
    }
)

# %% [markdown]
# ## Task 9: Custom Callback: Model Testing

# %%
def test_model(model, test_datagen):
  example, label = next(test_datagen)
  x = example['image']
  y = label['class_out']
  box = label['box_out']

  pred_y, pred_box = model.predict(x)

  pred_coords = pred_box[0]
  gt_coords = box[0]
  pred_class = np.argmax(pred_y[0])
  image = x[0]

  gt = emojis[np.argmax(y[0])]['name']
  pred_class_name = emojis[pred_class]['name']

  image = plot_bounding_box(image, gt_coords, pred_coords, norm=True)
  color = 'green' if gt == pred_class_name else 'red'

  plt.imshow(image)
  plt.xlabel(f'Pred: {pred_class_name}', color=color)
  plt.ylabel(f'GT: {gt}', color=color)
  plt.xticks([])
  plt.yticks([])

# %%
def test(model):
  test_datagen = data_generator(1)

  plt.figure(figsize=(16, 4))

  for i in range(0, 6):
    plt.subplot(1, 6, i + 1)
    test_model(model, test_datagen)
  plt.show()

# %%
test(model)

# %%
class ShowTestImages(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    test(self.model)

# %% [markdown]
# ## Task 10: Model Training

# %%
def lr_schedule(epoch, lr):
  if (epoch + 1) % 5 == 0:
    lr *= 0.2
  return max(lr, 3e-7)


_ = model.fit(
    data_generator(),
    epochs=50,
    steps_per_epoch=500,
    callbacks=[
               ShowTestImages(),
               tf.keras.callbacks.EarlyStopping(monitor='box_out_iou', patience=3, mode='max'),
               tf.keras.callbacks.LearningRateScheduler(lr_schedule)
    ]
)
# Out:
# Epoch 1/50
# 500/500 [==============================] - ETA: 0s - loss: 0.9754 - class_out_loss: 0.6764 - box_out_loss: 0.2990 - class_out_accuracy: 0.7706 - box_out_iou: 0.2300
# 500/500 [==============================] - 192s 379ms/step - loss: 0.9754 - class_out_loss: 0.6764 - box_out_loss: 0.2990 - class_out_accuracy: 0.7706 - box_out_iou: 0.2300 - lr: 0.0010
# Epoch 2/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0359 - class_out_loss: 0.0091 - box_out_loss: 0.0268 - class_out_accuracy: 0.9998 - box_out_iou: 0.2749
# 500/500 [==============================] - 185s 370ms/step - loss: 0.0359 - class_out_loss: 0.0091 - box_out_loss: 0.0268 - class_out_accuracy: 0.9998 - box_out_iou: 0.2749 - lr: 0.0010
# Epoch 3/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0146 - class_out_loss: 0.0028 - box_out_loss: 0.0118 - class_out_accuracy: 1.0000 - box_out_iou: 0.3321
# 500/500 [==============================] - 187s 374ms/step - loss: 0.0146 - class_out_loss: 0.0028 - box_out_loss: 0.0118 - class_out_accuracy: 1.0000 - box_out_iou: 0.3321 - lr: 0.0010
# Epoch 4/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0089 - class_out_loss: 0.0017 - box_out_loss: 0.0072 - class_out_accuracy: 1.0000 - box_out_iou: 0.3798
# 500/500 [==============================] - 186s 372ms/step - loss: 0.0089 - class_out_loss: 0.0017 - box_out_loss: 0.0072 - class_out_accuracy: 1.0000 - box_out_iou: 0.3798 - lr: 0.0010
# Epoch 5/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0041 - class_out_loss: 9.3235e-04 - box_out_loss: 0.0032 - class_out_accuracy: 1.0000 - box_out_iou: 0.4323
# 500/500 [==============================] - 180s 360ms/step - loss: 0.0041 - class_out_loss: 9.3235e-04 - box_out_loss: 0.0032 - class_out_accuracy: 1.0000 - box_out_iou: 0.4323 - lr: 2.0000e-04
# Epoch 6/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0033 - class_out_loss: 6.6285e-04 - box_out_loss: 0.0027 - class_out_accuracy: 1.0000 - box_out_iou: 0.4707
# 500/500 [==============================] - 172s 344ms/step - loss: 0.0033 - class_out_loss: 6.6285e-04 - box_out_loss: 0.0027 - class_out_accuracy: 1.0000 - box_out_iou: 0.4707 - lr: 2.0000e-04
# Epoch 7/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0028 - class_out_loss: 5.1101e-04 - box_out_loss: 0.0023 - class_out_accuracy: 1.0000 - box_out_iou: 0.5009
# 500/500 [==============================] - 175s 351ms/step - loss: 0.0028 - class_out_loss: 5.1101e-04 - box_out_loss: 0.0023 - class_out_accuracy: 1.0000 - box_out_iou: 0.5009 - lr: 2.0000e-04
# Epoch 8/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0028 - class_out_loss: 5.3799e-04 - box_out_loss: 0.0022 - class_out_accuracy: 1.0000 - box_out_iou: 0.5237
# 500/500 [==============================] - 179s 358ms/step - loss: 0.0028 - class_out_loss: 5.3799e-04 - box_out_loss: 0.0022 - class_out_accuracy: 1.0000 - box_out_iou: 0.5237 - lr: 2.0000e-04
# Epoch 9/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0027 - class_out_loss: 5.3593e-04 - box_out_loss: 0.0021 - class_out_accuracy: 1.0000 - box_out_iou: 0.5421
# 500/500 [==============================] - 173s 346ms/step - loss: 0.0027 - class_out_loss: 5.3593e-04 - box_out_loss: 0.0021 - class_out_accuracy: 1.0000 - box_out_iou: 0.5421 - lr: 2.0000e-04
# Epoch 10/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0019 - class_out_loss: 3.6943e-04 - box_out_loss: 0.0015 - class_out_accuracy: 1.0000 - box_out_iou: 0.5607
# 500/500 [==============================] - 176s 352ms/step - loss: 0.0019 - class_out_loss: 3.6943e-04 - box_out_loss: 0.0015 - class_out_accuracy: 1.0000 - box_out_iou: 0.5607 - lr: 4.0000e-05
# Epoch 11/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0017 - class_out_loss: 3.1598e-04 - box_out_loss: 0.0014 - class_out_accuracy: 1.0000 - box_out_iou: 0.5768
# 500/500 [==============================] - 182s 364ms/step - loss: 0.0017 - class_out_loss: 3.1598e-04 - box_out_loss: 0.0014 - class_out_accuracy: 1.0000 - box_out_iou: 0.5768 - lr: 4.0000e-05
# Epoch 12/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0017 - class_out_loss: 3.3166e-04 - box_out_loss: 0.0014 - class_out_accuracy: 1.0000 - box_out_iou: 0.5903
# 500/500 [==============================] - 189s 378ms/step - loss: 0.0017 - class_out_loss: 3.3166e-04 - box_out_loss: 0.0014 - class_out_accuracy: 1.0000 - box_out_iou: 0.5903 - lr: 4.0000e-05
# Epoch 13/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0016 - class_out_loss: 2.7154e-04 - box_out_loss: 0.0014 - class_out_accuracy: 1.0000 - box_out_iou: 0.6020
# 500/500 [==============================] - 183s 366ms/step - loss: 0.0016 - class_out_loss: 2.7154e-04 - box_out_loss: 0.0014 - class_out_accuracy: 1.0000 - box_out_iou: 0.6020 - lr: 4.0000e-05
# Epoch 14/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0016 - class_out_loss: 2.4536e-04 - box_out_loss: 0.0013 - class_out_accuracy: 1.0000 - box_out_iou: 0.6120
# 500/500 [==============================] - 164s 328ms/step - loss: 0.0016 - class_out_loss: 2.4536e-04 - box_out_loss: 0.0013 - class_out_accuracy: 1.0000 - box_out_iou: 0.6120 - lr: 4.0000e-05
# Epoch 15/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0014 - class_out_loss: 2.8106e-04 - box_out_loss: 0.0011 - class_out_accuracy: 1.0000 - box_out_iou: 0.6220
# 500/500 [==============================] - 176s 353ms/step - loss: 0.0014 - class_out_loss: 2.8106e-04 - box_out_loss: 0.0011 - class_out_accuracy: 1.0000 - box_out_iou: 0.6220 - lr: 8.0000e-06
# Epoch 16/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0014 - class_out_loss: 2.5316e-04 - box_out_loss: 0.0011 - class_out_accuracy: 1.0000 - box_out_iou: 0.6308
# 500/500 [==============================] - 159s 317ms/step - loss: 0.0014 - class_out_loss: 2.5316e-04 - box_out_loss: 0.0011 - class_out_accuracy: 1.0000 - box_out_iou: 0.6308 - lr: 8.0000e-06
# Epoch 17/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0014 - class_out_loss: 2.8900e-04 - box_out_loss: 0.0011 - class_out_accuracy: 1.0000 - box_out_iou: 0.6386
# 500/500 [==============================] - 181s 361ms/step - loss: 0.0014 - class_out_loss: 2.8900e-04 - box_out_loss: 0.0011 - class_out_accuracy: 1.0000 - box_out_iou: 0.6386 - lr: 8.0000e-06
# Epoch 18/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0013 - class_out_loss: 2.3766e-04 - box_out_loss: 0.0011 - class_out_accuracy: 1.0000 - box_out_iou: 0.6456
# 500/500 [==============================] - 183s 365ms/step - loss: 0.0013 - class_out_loss: 2.3766e-04 - box_out_loss: 0.0011 - class_out_accuracy: 1.0000 - box_out_iou: 0.6456 - lr: 8.0000e-06
# Epoch 19/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0013 - class_out_loss: 2.4592e-04 - box_out_loss: 0.0010 - class_out_accuracy: 1.0000 - box_out_iou: 0.6521
# 500/500 [==============================] - 188s 377ms/step - loss: 0.0013 - class_out_loss: 2.4592e-04 - box_out_loss: 0.0010 - class_out_accuracy: 1.0000 - box_out_iou: 0.6521 - lr: 8.0000e-06
# Epoch 20/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0012 - class_out_loss: 2.1526e-04 - box_out_loss: 0.0010 - class_out_accuracy: 1.0000 - box_out_iou: 0.6581
# 500/500 [==============================] - 191s 382ms/step - loss: 0.0012 - class_out_loss: 2.1526e-04 - box_out_loss: 0.0010 - class_out_accuracy: 1.0000 - box_out_iou: 0.6581 - lr: 1.6000e-06
# Epoch 21/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0012 - class_out_loss: 2.1795e-04 - box_out_loss: 0.0010 - class_out_accuracy: 1.0000 - box_out_iou: 0.6634
# 500/500 [==============================] - 197s 393ms/step - loss: 0.0012 - class_out_loss: 2.1795e-04 - box_out_loss: 0.0010 - class_out_accuracy: 1.0000 - box_out_iou: 0.6634 - lr: 1.6000e-06
# Epoch 22/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0013 - class_out_loss: 2.6344e-04 - box_out_loss: 0.0010 - class_out_accuracy: 1.0000 - box_out_iou: 0.6683
# 500/500 [==============================] - 168s 337ms/step - loss: 0.0013 - class_out_loss: 2.6344e-04 - box_out_loss: 0.0010 - class_out_accuracy: 1.0000 - box_out_iou: 0.6683 - lr: 1.6000e-06
# Epoch 23/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0013 - class_out_loss: 3.1405e-04 - box_out_loss: 9.6336e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6730
# 500/500 [==============================] - 160s 321ms/step - loss: 0.0013 - class_out_loss: 3.1405e-04 - box_out_loss: 9.6336e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6730 - lr: 1.6000e-06
# Epoch 24/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0012 - class_out_loss: 2.4079e-04 - box_out_loss: 9.5024e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6773
# 500/500 [==============================] - 163s 326ms/step - loss: 0.0012 - class_out_loss: 2.4079e-04 - box_out_loss: 9.5024e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6773 - lr: 1.6000e-06
# Epoch 25/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0011 - class_out_loss: 2.0374e-04 - box_out_loss: 9.4468e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6813
# 500/500 [==============================] - 163s 326ms/step - loss: 0.0011 - class_out_loss: 2.0374e-04 - box_out_loss: 9.4468e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6813 - lr: 3.2000e-07
# Epoch 26/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0011 - class_out_loss: 2.0835e-04 - box_out_loss: 9.3184e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6851
# 500/500 [==============================] - 168s 337ms/step - loss: 0.0011 - class_out_loss: 2.0835e-04 - box_out_loss: 9.3184e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6851 - lr: 3.2000e-07
# Epoch 27/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0011 - class_out_loss: 1.9375e-04 - box_out_loss: 9.0111e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6887
# 500/500 [==============================] - 181s 362ms/step - loss: 0.0011 - class_out_loss: 1.9375e-04 - box_out_loss: 9.0111e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6887 - lr: 3.2000e-07
# Epoch 28/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0011 - class_out_loss: 1.8747e-04 - box_out_loss: 9.1486e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6919
# 500/500 [==============================] - 175s 350ms/step - loss: 0.0011 - class_out_loss: 1.8747e-04 - box_out_loss: 9.1486e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6919 - lr: 3.2000e-07
# Epoch 29/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0011 - class_out_loss: 2.0129e-04 - box_out_loss: 9.3063e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6949
# 500/500 [==============================] - 172s 345ms/step - loss: 0.0011 - class_out_loss: 2.0129e-04 - box_out_loss: 9.3063e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6949 - lr: 3.2000e-07
# Epoch 30/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0011 - class_out_loss: 2.0333e-04 - box_out_loss: 9.1720e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6977
# 500/500 [==============================] - 170s 339ms/step - loss: 0.0011 - class_out_loss: 2.0333e-04 - box_out_loss: 9.1720e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.6977 - lr: 3.0000e-07
# Epoch 31/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0011 - class_out_loss: 1.9258e-04 - box_out_loss: 9.0282e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.7004
# 500/500 [==============================] - 169s 338ms/step - loss: 0.0011 - class_out_loss: 1.9258e-04 - box_out_loss: 9.0282e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.7004 - lr: 3.0000e-07
# Epoch 32/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0011 - class_out_loss: 1.9705e-04 - box_out_loss: 9.2285e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.7029
# 500/500 [==============================] - 166s 333ms/step - loss: 0.0011 - class_out_loss: 1.9705e-04 - box_out_loss: 9.2285e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.7029 - lr: 3.0000e-07
# Epoch 33/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0012 - class_out_loss: 2.1221e-04 - box_out_loss: 9.5136e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.7051
# 500/500 [==============================] - 167s 334ms/step - loss: 0.0012 - class_out_loss: 2.1221e-04 - box_out_loss: 9.5136e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.7051 - lr: 3.0000e-07
# Epoch 34/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0011 - class_out_loss: 2.0013e-04 - box_out_loss: 9.2272e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.7073
# 500/500 [==============================] - 168s 335ms/step - loss: 0.0011 - class_out_loss: 2.0013e-04 - box_out_loss: 9.2272e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.7073 - lr: 3.0000e-07
# Epoch 35/50
# 312/500 [=================>............] - ETA: 1:05 - loss: 0.0012 - class_out_loss: 2.0665e-04 - box_out_loss: 9.5059e-04 - class_out_accuracy: 1.0000 - box_out_iou: 0.7086
